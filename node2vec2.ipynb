# %%
from pecanpy import pecanpy as pp
import utils
import networkx as nx
import os
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from sklearn.svm import SVC
import json
from numpy.typing import NDArray
from typing import Dict
import pandas as pd
from sklearn.feature_selection import SelectPercentile, f_classif
from training import train_gnn
from torch_geometric.data import Data
import torch
import torch_geometric as pyg

# %%
# !pip install pecanpy
# !pip install torch_geometric
# !pip install seaborn
# !pip install scikit-learn
# Out:
# Requirement already satisfied: pecanpy in /opt/anaconda3/envs/ma42/lib/python3.9/site-packages (2.0.8)
# Requirement already satisfied: numpy>=1.20.0 in /opt/anaconda3/envs/ma42/lib/python3.9/site-packages (from pecanpy) (1.24.2)
# Requirement already satisfied: gensim>=4.1.0 in /opt/anaconda3/envs/ma42/lib/python3.9/site-packages (from pecanpy) (4.3.1)
# Requirement already satisfied: numba-progress>=0.0.2 in /opt/anaconda3/envs/ma42/lib/python3.9/site-packages (from pecanpy) (1.0.0)
# Requirement already satisfied: numba>=0.46.0 in /opt/anaconda3/envs/ma42/lib/python3.9/site-packages (from pecanpy) (0.57.0)
# Requirement already satisfied: nptyping>=2.0.0 in /opt/anaconda3/envs/ma42/lib/python3.9/site-packages (from pecanpy) (2.5.0)
# Requirement already satisfied: scipy>=1.7.0 in /opt/anaconda3/envs/ma42/lib/python3.9/site-packages (from gensim>=4.1.0->pecanpy) (1.8.1)
# Requirement already satisfied: smart-open>=1.8.1 in /opt/anaconda3/envs/ma42/lib/python3.9/site-packages (from gensim>=4.1.0->pecanpy) (6.3.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.0.0 in /opt/anaconda3/envs/ma42/lib/python3.9/site-packages (from nptyping>=2.0.0->pecanpy) (4.5.0)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in /opt/anaconda3/envs/ma42/lib/python3.9/site-packages (from numba>=0.46.0->pecanpy) (0.40.0)
# Requirement already satisfied: tqdm in /opt/anaconda3/envs/ma42/lib/python3.9/site-packages (from numba-progress>=0.0.2->pecanpy) (4.65.0)
# Requirement already satisfied: torch_geometric in /opt/anaconda3/envs/ma42/lib/python3.9/site-packages (2.3.1)
# Requirement already satisfied: scipy in /opt/anaconda3/envs/ma42/lib/python3.9/site-packages (from torch_geometric) (1.8.1)
# Requirement already satisfied: pyparsing in /opt/anaconda3/envs/ma42/lib/python3.9/site-packages (from torch_geometric) (3.0.9)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/ma42/lib/python3.9/site-packages (from torch_geometric) (1.24.2)
# Requirement already satisfied: scikit-learn in /opt/anaconda3/envs/ma42/lib/python3.9/site-packages (from torch_geometric) (1.2.2)
# Requirement already satisfied: psutil>=5.8.0 in /opt/anaconda3/envs/ma42/lib/python3.9/site-packages (from torch_geometric) (5.9.5)
# Requirement already satisfied: tqdm in /opt/anaconda3/envs/ma42/lib/python3.9/site-packages (from torch_geometric) (4.65.0)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/ma42/lib/python3.9/site-packages (from torch_geometric) (3.1.2)
# Requirement already satisfied: requests in /opt/anaconda3/envs/ma42/lib/python3.9/site-packages (from torch_geometric) (2.28.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/ma42/lib/python3.9/site-packages (from jinja2->torch_geometric) (2.1.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/anaconda3/envs/ma42/lib/python3.9/site-packages (from requests->torch_geometric) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/ma42/lib/python3.9/site-packages (from requests->torch_geometric) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/ma42/lib/python3.9/site-packages (from requests->torch_geometric) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/ma42/lib/python3.9/site-packages (from requests->torch_geometric) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /opt/anaconda3/envs/ma42/lib/python3.9/site-packages (from scikit-learn->torch_geometric) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/envs/ma42/lib/python3.9/site-packages (from scikit-learn->torch_geometric) (3.1.0)
# Collecting seaborn
#   Using cached seaborn-0.12.2-py3-none-any.whl (293 kB)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /opt/anaconda3/envs/ma42/lib/python3.9/site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: pandas>=0.25 in /opt/anaconda3/envs/ma42/lib/python3.9/site-packages (from seaborn) (2.0.1)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /opt/anaconda3/envs/ma42/lib/python3.9/site-packages (from seaborn) (1.24.2)
# Requirement already satisfied: pillow>=6.2.0 in /opt/anaconda3/envs/ma42/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.5.0)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/ma42/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/ma42/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/ma42/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /opt/anaconda3/envs/ma42/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (5.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/ma42/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.39.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/ma42/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/envs/ma42/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/ma42/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/ma42/lib/python3.9/site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/envs/ma42/lib/python3.9/site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: zipp>=3.1.0 in /opt/anaconda3/envs/ma42/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.1->seaborn) (3.15.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/ma42/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.12.2
# Requirement already satisfied: scikit-learn in /opt/anaconda3/envs/ma42/lib/python3.9/site-packages (1.2.2)
# Requirement already satisfied: scipy>=1.3.2 in /opt/anaconda3/envs/ma42/lib/python3.9/site-packages (from scikit-learn) (1.8.1)
# Requirement already satisfied: joblib>=1.1.1 in /opt/anaconda3/envs/ma42/lib/python3.9/site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/envs/ma42/lib/python3.9/site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: numpy>=1.17.3 in /opt/anaconda3/envs/ma42/lib/python3.9/site-packages (from scikit-learn) (1.24.2)

# %%
def init_result_folder(path: str) -> nx.Graph:
    if not os.path.exists(os.path.join(path, 'results')):
        os.mkdir(os.path.join(path, 'results'))

    with open(os.path.join(path, 'results', 'results.json'), 'w') as f:
        json.dump(dict(), f)

    path_split = path.split('/')
    city_name = path_split[-1]
    data_dir = os.path.join(*path_split[:-1])
    graph, _ = utils.create_city_graph(city_name, data_dir)
    graph = nx.DiGraph(graph)

    mapping = {k: i for i, k in enumerate(sorted(graph.nodes()))}
    graph = nx.relabel_nodes(graph, mapping)

    path_edg_file = os.path.join(path, 'adj_mat.edg')
    nx.write_edgelist(graph, path_edg_file, data=False, delimiter='\t')

    return graph


def save_embeddings(path: str, p: float, q: float, num_walks: int, dim: int = 256) -> NDArray[np.float_]:
    path_edg_file = os.path.join(path, 'adj_mat.edg')

    g = pp.SparseOTF(p=p, q=q, verbose=False, workers=16)
    g.read_edg(path_edg_file, weighted=False, directed=True)

    embeddings = g.embed(dim=dim, num_walks=num_walks)

    np.save(os.path.join(path, 'results', 'node2vec_embeddings.npy'), embeddings)

    return embeddings


def train_svm(features: NDArray[np.float_], targets: NDArray[np.float_], seed: int = 42,scale_features=False) -> Dict:
    X_train, X_test, y_train, y_test = train_test_split(features, targets, test_size=0.2, stratify=targets, random_state=seed)

    model = SVC(class_weight='balanced', C=1)
    if scale_features:
        standard_scaler = StandardScaler()
        standard_scaler.fit(X_train)
        X_train = standard_scaler.transform(X_train)
        
        X_test = standard_scaler.transform(X_test)

        #score = f_classif(X_train,y_train)
        #print(score[0])
    model.fit(X_train, y_train)

    train_preds = model.predict(X_train)
    test_preds = model.predict(X_test)

    results = {}
    results['train'] = classification_report(y_train, train_preds, output_dict=True)
    results['test'] = classification_report(y_test, test_preds, output_dict=True)

    return results


def cities_loop(data_path: str, p: float, q: float, num_walks: int, dim: int) -> None:

    for entry in os.scandir(data_path):
        if entry.is_dir():
            city = entry.name
            
            print(f"Start training for city {city}")
            graph = init_result_folder(entry.path)
            embeddings = save_embeddings(entry.path, p, q, num_walks=num_walks, dim=dim)
            
            targets = dict(graph.nodes(data='city_center'))
            targets = np.array([targets[v] for v in range(len(targets))])
            
            results = train_svm(embeddings, targets)
            df_features = pd.read_csv(os.path.join(data_path,"handcrafted_features.csv"))
            df_features = df_features[df_features["city"]==city]
            targets_handcrafted = df_features["city_center"].values
           
            features_handcrafted = df_features.drop(["stop_I","name","city_center","city","Unnamed: 0"],axis=1)

            results_handcrafted =  train_svm(features_handcrafted, targets_handcrafted,scale_features=True)

            with open(os.path.join(entry.path, 'results', 'results.json'), 'r') as f:
                res_dict = json.load(f)
            res_dict['baseline_svm'] = results
            res_dict["handcrafted_svm"] = results_handcrafted

            with open(os.path.join(entry.path, 'results', 'results.json'), 'w') as f:
                json.dump(res_dict, f)


def cities_loop_gnn(data_path: str, seed: int = 42) -> None:

    for entry in os.scandir(data_path):
        if entry.is_dir():
            city = entry.name
            
            df_features = pd.read_csv(os.path.join(data_path,"handcrafted_features.csv"))
            df_features = df_features[df_features["city"]==city]
            targets_handcrafted = df_features["city_center"].values
            features_handcrafted = df_features.drop(["stop_I", "name", "city_center", "city","Unnamed: 0"],axis=1).values
            graph = nx.read_edgelist(os.path.join(entry.path, 'adj_mat.edg'), create_using=nx.DiGraph)

            
            print(f'number of edges in nx graph : {graph.number_of_edges()}')
            adj_mat = nx.adjacency_matrix(graph, weight=None) # not weighted
            print(f'adj mat shape : {adj_mat.shape}')
            edge_index, _ = pyg.utils.from_scipy_sparse_matrix(adj_mat)
            print(f'adj mat shape sparse tensor : {edge_index.shape}')

            d = Data(
                x=torch.from_numpy(features_handcrafted),
                y=torch.tensor(targets_handcrafted).clone(),
                edge_index=edge_index.clone(),
            )

            train_ids, test_ids = train_test_split(
                np.arange(features_handcrafted.shape[0]), test_size=0.2, stratify=targets_handcrafted, random_state=seed
            )

            train_ids, val_ids = train_test_split(
                train_ids, test_size=0.2, stratify=targets_handcrafted[train_ids], random_state=seed
            )

            pos_weight = np.sum(targets_handcrafted[train_ids] == 0) / np.sum(targets_handcrafted[train_ids] == 1)
            print(f'Pos weight : {pos_weight}')

            results_gnn = train_gnn(
                [d],
                train_ids,
                val_ids,
                test_ids,
                pos_weight=pos_weight,
                model_name='gnn',
                lr=1e-3,
                epochs=20,
                out_channels_graph=16,
                in_channels_graph=18,
                heads=5,
                dropout=0.0
            )
            results_gat = train_gnn(
                [d],
                train_ids,
                val_ids,
                test_ids,
                pos_weight=pos_weight,
                model_name='gat',
                lr=1e-3,
                epochs=20,
                out_channels_graph=16,
                in_channels_graph=18,
                heads=5,
                dropout=0.0
            )

            with open(os.path.join(entry.path, 'results', 'results.json'), 'r') as f:
                res_dict = json.load(f)
            print()
            res_dict['gnn'] = results_gnn
            res_dict["gat"] = results_gat

            with open(os.path.join(entry.path, 'results', 'results.json'), 'w') as f:
                json.dump(res_dict, f)

# %%
cities_loop("data",p=5.0, q=0.1, num_walks=100,dim=256)
# Out:
# Start training for city paris
# Start training for city detroit
# Start training for city melbourne
# Start training for city luxembourg
# Start training for city helsinki
# Start training for city dublin
# Start training for city adelaide
# Start training for city palermo
# Start training for city turku
# Start training for city toulouse
# Start training for city canberra
# Start training for city nantes
# Start training for city kuopio
# Start training for city sydney
# Start training for city lisbon
# Start training for city rennes
# Start training for city belfast
# Start training for city brisbane
# Start training for city bordeaux
# Start training for city venice
# Start training for city grenoble
# Start training for city winnipeg
# Start training for city prague
# Start training for city berlin
# Start training for city rome

# %%
best_p = -1
best_q = -1
best_score = -1
attempts = []
for p in [0.1, 1.0, 5.0]:
    for q in [0.1, 0.5, 1.0, 2.0, 5.0]:
        f1_train = []
        f1_val = []
        for city in ["turku","detroit","paris","adelaide"]:
            print(f"starting training for {city} with p={p} and q={q}")
            city_name = city
            data_dir = 'data'
            graph, _ = utils.create_city_graph(city_name, data_dir)
            graph = nx.DiGraph(graph)

            mapping = {k: i for i, k in enumerate(sorted(graph.nodes()))}
            graph = nx.relabel_nodes(graph, mapping)

            path_edg_file = os.path.join(data_dir, city_name, 'adj_mat.edg')
            nx.write_edgelist(graph, path_edg_file, data=False, delimiter='\t')
            g = pp.SparseOTF(p=p, q=q, verbose=False, workers=16)
            g.read_edg(path_edg_file, weighted=False, directed=True)

            embeddings = g.embed(dim=256, num_walks=100)

            targets = dict(graph.nodes(data='city_center'))
            targets = np.array([targets[v] for v in range(len(targets))])
            X_train, X_test, y_train, y_test = train_test_split(embeddings, targets, test_size=0.2, stratify=targets,random_state=42)
            X_train, X_val, y_train, y_val = train_test_split(X_train,y_train,test_size=0.15,stratify=y_train,random_state=42)
            model = SVC(class_weight='balanced', C=1)
            model.fit(X_train, y_train)

            train_preds = model.predict(X_train)
            train_rep = classification_report(y_train, train_preds,output_dict=True)
            val_preds = model.predict(X_val)
            val_rep = classification_report(y_val, val_preds,output_dict=True)

            f1_train.append(train_rep["1"]["f1-score"])
            f1_val.append(val_rep["1"]["f1-score"])
           
        avg_f1_train = np.mean(f1_train)
        avg_f1_val = np.mean(f1_val)
        attempts.append({"p":p,"q":q,"score_train":avg_f1_train,"score_val":avg_f1_val})

        if avg_f1_val  > best_score:
            best_score = avg_f1_val
            best_p = p
            best_q = q
print(f"best parameters with p={best_p} and q={best_q} and f1 {best_score}")
# Out:
# starting training for turku with p=0.1 and q=0.1
# starting training for detroit with p=0.1 and q=0.1
# starting training for paris with p=0.1 and q=0.1
# starting training for adelaide with p=0.1 and q=0.1
# starting training for turku with p=0.1 and q=0.5
# starting training for detroit with p=0.1 and q=0.5
# starting training for paris with p=0.1 and q=0.5
# starting training for adelaide with p=0.1 and q=0.5
# starting training for turku with p=0.1 and q=1.0
# starting training for detroit with p=0.1 and q=1.0
# starting training for paris with p=0.1 and q=1.0
# starting training for adelaide with p=0.1 and q=1.0
# starting training for turku with p=0.1 and q=2.0
# starting training for detroit with p=0.1 and q=2.0
# starting training for paris with p=0.1 and q=2.0
# starting training for adelaide with p=0.1 and q=2.0
# starting training for turku with p=0.1 and q=5.0
# starting training for detroit with p=0.1 and q=5.0
# starting training for paris with p=0.1 and q=5.0
# starting training for adelaide with p=0.1 and q=5.0
# starting training for turku with p=1.0 and q=0.1
# starting training for detroit with p=1.0 and q=0.1
# starting training for paris with p=1.0 and q=0.1
# starting training for adelaide with p=1.0 and q=0.1
# starting training for turku with p=1.0 and q=0.5
# starting training for detroit with p=1.0 and q=0.5
# starting training for paris with p=1.0 and q=0.5
# starting training for adelaide with p=1.0 and q=0.5
# starting training for turku with p=1.0 and q=1.0
# starting training for detroit with p=1.0 and q=1.0
# starting training for paris with p=1.0 and q=1.0
# starting training for adelaide with p=1.0 and q=1.0
# starting training for turku with p=1.0 and q=2.0
# starting training for detroit with p=1.0 and q=2.0
# starting training for paris with p=1.0 and q=2.0
# starting training for adelaide with p=1.0 and q=2.0
# starting training for turku with p=1.0 and q=5.0
# starting training for detroit with p=1.0 and q=5.0
# starting training for paris with p=1.0 and q=5.0
# starting training for adelaide with p=1.0 and q=5.0
# starting training for turku with p=5.0 and q=0.1
# starting training for detroit with p=5.0 and q=0.1
# starting training for paris with p=5.0 and q=0.1
# starting training for adelaide with p=5.0 and q=0.1
# starting training for turku with p=5.0 and q=0.5
# starting training for detroit with p=5.0 and q=0.5
# starting training for paris with p=5.0 and q=0.5
# starting training for adelaide with p=5.0 and q=0.5
# starting training for turku with p=5.0 and q=1.0
# starting training for detroit with p=5.0 and q=1.0
# starting training for paris with p=5.0 and q=1.0
# starting training for adelaide with p=5.0 and q=1.0
# starting training for turku with p=5.0 and q=2.0
# starting training for detroit with p=5.0 and q=2.0
# starting training for paris with p=5.0 and q=2.0
# starting training for adelaide with p=5.0 and q=2.0
# starting training for turku with p=5.0 and q=5.0
# starting training for detroit with p=5.0 and q=5.0
# starting training for paris with p=5.0 and q=5.0
# starting training for adelaide with p=5.0 and q=5.0
# best parameters with p=5.0 and q=0.1 and f1 0.4916539654532579

# %%
import json
with open("save_p_q.json","w") as f:
    json.dump(attempts,f)

# %%
embeddings.shape
# Out:
# (1850, 256)

# %%
import seaborn as sns
lst = []
for entry in sorted(os.scandir("data"),key=lambda x: x.name):
    if entry.is_dir():
        city = entry.name
        with open(os.path.join(entry.path, 'results', 'results.json'), 'r') as f:
            res_dict = json.load(f)

        lst.append((city,"node2vec",res_dict["baseline_svm"]["test"]["1"]["f1-score"]))
        lst.append((city,"handcrafted",res_dict["handcrafted_svm"]["test"]["1"]["f1-score"]))
df = pd.DataFrame(lst,columns=["city","type","score"])
ax = sns.barplot(df, x="city",y="score",hue="type")
ax.tick_params(labelrotation=90) 
ax.legend(bbox_to_anchor=(1.1, 1.05),loc="upper left")

# %%
# Out:
# SVC(C=1, class_weight='balanced')

# %%
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.79      0.87      1212
#            1       0.49      0.90      0.63       268
#
#     accuracy                           0.81      1480
#    macro avg       0.73      0.85      0.75      1480
# weighted avg       0.88      0.81      0.83      1480

# %%
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.67      0.74       303
#            1       0.18      0.33      0.23        67
#
#     accuracy                           0.61       370
#    macro avg       0.50      0.50      0.49       370
# weighted avg       0.70      0.61      0.65       370
